# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv()

nyt_api_key = os.getenv("NYT_API_KEY")
tmdb_api_key = os.getenv("TMDB_API_KEY")
type (nyt_api_key)
# Out:
# str

# %%
https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=yourkey
# Out:
#   Cell In[53], line 1
#     https://api.nytimes.com/svc/search/v2/articlesearch.json?q=election&api-key=yourkey
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (f"{url}api-key={nyt_api_key}&fq={filter_query}&sort={sort}&fl={field_list}&begin_date={begin_date}&end_date={end_date}")
             
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=QnhhFc4VSixKtaKnqu2gYpJNA9NolJFA&fq=section_name:"Movies" AND type_of_material:"Review" AND headline:"love"&sort=newest&fl=headline,web_url,snippet,source,keywords,pub_date,byline,word_count&begin_date=20130101&end_date=20230531'

# %%
# Create an empty list to store the reviews
review_list=[]

# loop through pages 0-19
for page in range (0,20):
    # create query with a page number
    # API results show 10 articles at a time
    page_query_url=f"{query_url}&page={page}"
    
    # Make a "GET" request and retrieve the JSON
    reviews=requests.get(page_query_url).json()
    
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
    
    # Try and save the reviews to the reviews_list
    try:
        # loop through the reviews["response"]["docs"] and append each review to the list
        for review in reviews["response"]["docs"]:
            review_list.append(review)
        # Print the page that was just retrieved
        print(f"checked page {page}") 

        # Print the page number that had no results then break from the loop
    except:
        print(f"no results found at {page}")
# Out:
# checked page 0
# checked page 1
# checked page 2
# checked page 3
# checked page 4
# checked page 5
# checked page 6
# checked page 7
# checked page 8
# checked page 9
# checked page 10
# checked page 11
# checked page 12
# checked page 13
# checked page 14
# checked page 15
# checked page 16
# checked page 17
# checked page 18
# checked page 19

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
print(json.dumps(review_list[:5],indent=4))
# Out:
# [
#     {
#         "web_url": "https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html",
#         "snippet": "A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.",
#         "source": "The New York Times",
#         "headline": {
#             "main": "\u2018The Attachment Diaries\u2019 Review: Love, Sick",
#             "kicker": null,
#             "content_kicker": null,
#             "print_headline": "The Attachment Diaries",
#             "name": null,
#             "seo": null,
#             "sub": null
#         },
#         "keywords": [
#             {
#                 "name": "subject",
#                 "value": "Movies",
#                 "rank": 1,
#                 "major": "N"
#             },
#             {
#                 "name": "creative_works",
#                 "value": "The Attachment Diaries (Movie)",
#                 "rank": 2,
#                 "major": "N"
# ...

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
review_df=pd.json_normalize(review_list)
review_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
review_df["title"]=review_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
review_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
review_df["Keywords"]=review_df["keywords"].apply(extract_keywords)
review_df
# Out:
#                                                web_url  \
# 0    https://www.nytimes.com/2023/05/25/movies/the-...
# 1    https://www.nytimes.com/2023/05/04/movies/what...
# 2    https://www.nytimes.com/2023/05/04/movies/you-...
# 3    https://www.nytimes.com/2023/04/21/movies/a-to...
# 4    https://www.nytimes.com/2023/04/20/movies/othe...
# ..                                                 ...
# 195  https://www.nytimes.com/2017/03/09/movies/the-...
# 196  https://www.nytimes.com/2017/03/09/movies/revi...
# 197  https://www.nytimes.com/2017/03/02/movies/love...
# 198  https://www.nytimes.com/2017/02/16/movies/ever...
# 199  https://www.nytimes.com/2017/02/09/movies/kedi...
#
#                                                snippet              source  \
# 0    A gynecologist and her patient form a horrifyi...  The New York Times
# 1    Two childhood friends navigate cultural differ...  The New York Times
# 2    Religion comes between two girls falling in lo...  The New York Times
# ...

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title=review_df["title"].to_list()
title
# Out:
# ['The Attachment Diaries',
#  'What’s Love Got to Do With It?’ Probably a Lo',
#  'You Can Live Forever',
#  'A Tourist’s Guide to Love',
#  'Other People’s Children',
#  'One True Loves',
#  'The Lost Weekend: A Love Story',
#  'A Thousand and One',
#  'Your Place or Mine',
#  'Love in the Time of Fentanyl',
#  'Pamela, a Love Story',
#  'In From the Side',
#  'After Love',
#  'Alcarràs',
#  'Nelly & Nadine',
#  'Lady Chatterley’s Lover',
#  'The Sound of Christmas',
#  'The Inspection',
#  'Bones and All',
#  'My Policeman',
#  'About Fate',
#  'Waiting for Bojangles',
#  'I Love My Dad',
#  'A Love Song',
#  'Alone Together',
#  'Art of Love',
#  'The Wheel',
#  'Thor: Love and Thunder',
#  'Both Sides of the Blade',
#  'Fire of Love',
#  'Love & Gelato',
#  'Stay Prayed Up',
#  'Benediction',
#  'Dinner in America',
#  'In a New York Minute',
#  'Anaïs in Love',
#  'I Love America',
#  'See You Then',
#  'La Mami',
#  'Love After Love',
#  'Deep Water',
#  'Lucy and Desi',
# ...

# %%
review_df.to_csv("save_review.csv")

# %% [markdown]
# ### Access The Movie Database API

# %%
## Access The Movie Database API
url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
# Create an empty list to store the results

# List of movie titles to search for
movie_titles = [
    "The Attachment Diaries", "What’s Love Got to Do With It?", "You Can Live Forever",
    "A Tourist’s Guide to Love", "Other People’s Children", "One True Loves",
    "The Lost Weekend: A Love Story", "A Thousand and One", "Your Place or Mine",
    "Love in the Time of Fentanyl", "Pamela, a Love Story", "In From the Side",
    "After Love", "Alcarràs", "Nelly & Nadine", "Lady Chatterley’s Lover",
    "The Sound of Christmas", "The Inspection", "Bones and All", "My Policeman",
    "About Fate", "Waiting for Bojangles", "I Love My Dad", "A Love Song", "Alone Together",
    "Love & Taxes", "Everybody Loves Somebody"
]

# Create an empty list to store results
tmdb_movies_list = []

# Counter to manage API request rate limiting
request_counter = 0
max_requests = 200

# Process each title
for title in movie_titles:
    if request_counter >= max_requests:
        print("Sleeping at 200 requests")
        time.sleep(60)  # Sleep for 60 seconds
        request_counter = 0  # reset counter after sleeping

    request_counter += 1

    try:
        search_url = f"https://api.themoviedb.org/3/search/movie?api_key={tmdb_api_key}&query={title}"
        response = requests.get(search_url)
        data = response.json()

        if data['total_results'] == 0:
            print(f"{title} not found.")
            continue

        # Assume taking the first result as the correct movie
        movie_id = data['results'][0]['id']
        movie_title = data['results'][0]['title']

        # Optional: Fetch more details using movie_id if needed
        details_url = f"https://api.themoviedb.org/3/movie/{movie_id}?api_key={tmdb_api_key}"
        details_response = requests.get(details_url)
        details_data = details_response.json()

        # Extract and print details
        print(f"Found {movie_title}")

        # Save details in list if needed
        tmdb_movies_list.append(details_data)

    except Exception as e:
        print(f"Error processing {title}: {str(e)}")

print("Finished processing all movie titles.")
# Out:
# Found The Attachment Diaries
# Found What's Love Got to Do with It?
# Found You Can Live Forever
# Found A Tourist's Guide to Love
# Found Other People's Children
# Found One True Loves
# Found The Lost Weekend: A Love Story
# Found A Thousand and One
# Found Your Place or Mine
# Found Love in the Time of Fentanyl
# Found Pamela, A Love Story
# Found In from the Side
# Found After Love
# Found Alcarràs
# Found Nelly and Monsieur Arnaud
# Found Lady Chatterley's Lover
# Found The Sound of Christmas
# Found The Inspection
# Found Bones and All
# Found My Policeman
# Found About Fate
# Found Waiting for Bojangles
# Found I Love My Dad
# Found A Love Song
# Found Alone Together
# Found Love, Divided
# Found Everybody Loves Somebody
# Finished processing all movie titles.

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data
first_five_movies = tmdb_movies_list[:5]
formatted_json = json.dumps(first_five_movies, indent=4)            
print("Preview of the first 5 movie details in JSON format:")
print(formatted_json)
# Out:
# Preview of the first 5 movie details in JSON format:
# [
#     {
#         "adult": false,
#         "backdrop_path": null,
#         "belongs_to_collection": null,
#         "budget": 0,
#         "genres": [
#             {
#                 "id": 18,
#                 "name": "Drama"
#             },
#             {
#                 "id": 9648,
#                 "name": "Mystery"
#             },
#             {
#                 "id": 53,
#                 "name": "Thriller"
#             },
#             {
#                 "id": 27,
#                 "name": "Horror"
#             }
#         ],
#         "homepage": "",
#         "id": 743040,
#         "imdb_id": "tt11359158",
#         "origin_country": [
#             "ES"
#         ],
#         "original_language": "es",
#         "original_title": "El apego",
# ...

# %%
# Convert the results to a DataFrame
movies_df = pd.json_normalize(tmdb_movies_list)
movies_df.head(2)
# Out:
#    adult                     backdrop_path belongs_to_collection  budget  \
# 0  False                              None                  None       0
# 1  False  /6CTHr1V5pi7PyZEyOyqmElsiHAO.jpg                  None       0
#
#                                               genres homepage      id  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...           743040
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...           800301
#
#       imdb_id origin_country original_language  ... release_date   revenue  \
# 0  tt11359158           [ES]                es  ...   2021-10-07         0
# 1  tt13430858           [GB]                en  ...   2023-01-26  10898395
#
#    runtime                                   spoken_languages    status  \
# 0      102  [{'english_name': 'Spanish', 'iso_639_1': 'es'...  Released
# 1      109  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
#
#   tagline                           title  video  vote_average vote_count
# ...

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title
merged_df = pd.merge(movies_df, review_df, on='title', how='inner')
merged_df. head(2)
# Out:
#    adult                     backdrop_path belongs_to_collection  budget  \
# 0  False                              None                  None       0
# 1  False  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                  None       0
#
#                                               genres  \
# 0  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 1  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                             homepage      id     imdb_id  \
# 0                                                     743040  tt11359158
# 1  https://gooddeedentertainment.com/you-can-live...  887580  tt15782570
#
#   origin_country original_language  ... headline.kicker  \
# 0           [ES]                es  ...            None
# 1           [CA]                en  ...            None
#
#   headline.content_kicker  headline.print_headline headline.name headline.seo  \
# 0                    None   The Attachment Diaries          None         None
# ...

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing
# Create a list of characters to remove
# Loop through the list of columns to fix
    # Convert the column to type 'str'
    # Loop through characters to remove
# Display the fixed DataFrame
# Assuming 'merged_df' is your existing DataFrame that needs cleaning
# Create a list of the columns that need fixing
columns_to_fix = ['genres', 'byline.person','origin_country']  # Adjust these column names based on your DataFrame

# Create a list of characters to remove: list brackets and quotation marks
chars_to_remove = ["[", "]", "'", '"', ':', "{", "}"]

# Loop through the list of columns to fix
for column in columns_to_fix:
    # Convert the column to type 'str'
    merged_df[column] = merged_df[column].astype(str)

    # Loop through characters to remove
    for char in chars_to_remove:
        merged_df[column] = merged_df[column].str.replace(char, '', regex=False)

# Display the fixed DataFrame
print("Fixed DataFrame:")
merged_df.head(2)
# Out:
# Fixed DataFrame:
#    adult                     backdrop_path belongs_to_collection  budget  \
# 0  False                              None                  None       0
# 1  False  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                  None       0
#
#                                               genres  \
# 0  id 18, name Drama, id 9648, name Mystery, id 5...
# 1          id 18, name Drama, id 10749, name Romance
#
#                                             homepage      id     imdb_id  \
# 0                                                     743040  tt11359158
# 1  https://gooddeedentertainment.com/you-can-live...  887580  tt15782570
#
#   origin_country original_language  ... headline.kicker  \
# 0             ES                es  ...            None
# 1             CA                en  ...            None
#
#   headline.content_kicker  headline.print_headline headline.name headline.seo  \
# 0                    None   The Attachment Diaries          None         None
# ...

# %%
# Drop "byline.person" column
merged_df = merged_df.drop(columns=['byline.person'])
print("DataFrame after dropping the 'byline.person' column:")
merged_df.head(2)
# Out:
# DataFrame after dropping the 'byline.person' column:
#    adult                     backdrop_path belongs_to_collection  budget  \
# 0  False                              None                  None       0
# 1  False  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                  None       0
#
#                                               genres  \
# 0  id 18, name Drama, id 9648, name Mystery, id 5...
# 1          id 18, name Drama, id 10749, name Romance
#
#                                             homepage      id     imdb_id  \
# 0                                                     743040  tt11359158
# 1  https://gooddeedentertainment.com/you-can-live...  887580  tt15782570
#
#   origin_country original_language  ...  \
# 0             ES                es  ...
# 1             CA                en  ...
#
#                                        headline.main headline.kicker  \
# 0        ‘The Attachment Diaries’ Review: Love, Sick            None
# ...

# %%
#Finding the columns have data in list

def find_list_columns(df):
    list_columns = []
    for column in df.columns:
        # Check if any item in the column is a list
        if df[column].apply(lambda x: isinstance(x, list)).any():
            list_columns.append(column)
    return list_columns

# Using the function to find list-containing columns in merged_df
columns_with_lists = find_list_columns(merged_df)

# Print the names of columns that contain lists
print("Columns containing lists:", columns_with_lists)
# Convert list columns to a string representation
for column in columns_with_lists:
    merged_df[column] = merged_df[column].apply(lambda x: ', '.join(map(str, x)) if isinstance(x, list) else x)
# Delete duplicate rows and reset index   
merged_df = merged_df.drop_duplicates()
merged_df = merged_df.reset_index(drop=True)
print("DataFrame after removing duplicates and resetting index:")
merged_df.head(2)
# Out:
# Columns containing lists: ['production_companies', 'production_countries', 'spoken_languages', 'keywords']
# DataFrame after removing duplicates and resetting index:
#    adult                     backdrop_path belongs_to_collection  budget  \
# 0  False                              None                  None       0
# 1  False  /sClvKM8C6a1DSPzMwkKjk8pNFDx.jpg                  None       0
#
#                                               genres  \
# 0  id 18, name Drama, id 9648, name Mystery, id 5...
# 1          id 18, name Drama, id 10749, name Romance
#
#                                             homepage      id     imdb_id  \
# 0                                                     743040  tt11359158
# 1  https://gooddeedentertainment.com/you-can-live...  887580  tt15782570
#
#   origin_country original_language  ...  \
# 0             ES                es  ...
# 1             CA                en  ...
#
# ...

# %%
# Export data to CSV without the index
merged_df.to_csv('merged_data.csv', index=False)

# Print confirmation message
print("DataFrame exported to CSV without the index.")
# Out:
# DataFrame exported to CSV without the index.
